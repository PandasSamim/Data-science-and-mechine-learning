# %% [markdown]
# ##What is a Pandas Series?
# A **Series** is a **one-dimensional labelled array** in **Pandas** (Python library) that can hold any data type: integers, floats, strings, etc.
#
# Think of it as a **column in Excel** with row labels (index).

# %% [markdown]
# ##How to Create a Series
# First, make sure Pandas is installed:
#
# **pip install pandas**

# %% [markdown]
# Then:

# %%
import pandas as pd
# From a list
s1=pd.Series([10,20,30,40])
print(s1)

# From a list with coustom index
s2=pd.Series([10,20,30,40], index=['a','b','c','d'])
print(s2)

# From a dictionary
s3=pd.Series({'a':100,'b':200,'c':300})
print(s3)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ##Indexing in Series
# You can access elements using:

# %%
s2[0] #10 by position
# Out:
# <ipython-input-10-33a9742e9cb6>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   s2[0] #10 by position
# np.int64(10)

# %%
s2['b'] #20 by index
# Out:
# np.int64(20)

# %% [markdown]
# Slicing

# %%
s2[1:3] # b and c
# Out:
# b    20
# c    30
# dtype: int64

# %%
s2[1:4] # b to d
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %%
s2[::2] # Every 2nd element
# Out:
# a    10
# c    30
# dtype: int64

# %%
s2[::-1] # reverse
# Out:
# d    40
# c    30
# b    20
# a    10
# dtype: int64

# %%
s2['a':'d'] # a to d
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
s2[s2>25] # Conditional slicing
# Out:
# c    30
# d    40
# dtype: int64

# %%
s2.iloc[1:4] # Index by position
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %%
s2.loc['b':'d'] # index by label
# Out:
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# ##Attributes of Series
# Useful built-in attributes:

# %%
s2.index # Index label
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
s2.values # values
# Out:
# array([10, 20, 30, 40])

# %%
s2.dtype # data type
# Out:
# dtype('int64')

# %%
s2.shape #shape (4,)
# Out:
# (4,)

# %%
print(s2.name) # serie name
# default none
# Out:
# None

# %% [markdown]
# ##Operations on Series
# You can perform vectorized operations (like NumPy):

# %%
s=pd.Series([1,2,3,4])

# %%
s+2 # add 2 every element
# Out:
# 0    3
# 1    4
# 2    5
# 3    6
# dtype: int64

# %%
s * 3 # Multiply each by 3
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
s.mean()   # Average
# Out:
# np.float64(2.5)

# %%
s.max() # Max value
# Out:
# 4

# %%
#Also supports element-wise comparison:

s > 2 # Boolean Series
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# dtype: bool

# %% [markdown]
# ##Practice Task
# Try this:

# %%
data=[5,10,15,20]
lables=['math','science','english','bengali']

# %%
s=pd.Series(data,index=lables)

# %% [markdown]
# Print 2nd subject marks

# %%
s['science']
# Out:
# np.int64(10)

# %% [markdown]
# Add 5 marks each

# %%
s+5
# Out:
# math       10
# science    15
# english    20
# bengali    25
# dtype: int64

# %% [markdown]
# Subject with marks>10

# %%
s[s>10]
# Out:
# english    15
# bengali    20
# dtype: int64

# %% [markdown]
# ##Quiz: Pandas Series (5 Questions)
#
# ###1.What is the output of the following code?
#
# import pandas as pd
# s = pd.Series([100, 200, 300], index=['a', 'b', 'c'])
# print(s['b'])
#
# a) 100
# b) 200
# c) 'b'
# d) Error
#
# **Ans:**200
#
#
# ###2. Which method returns the average of all values in a Series?
#
# a) s.average()
# b) s.mean()
# c) s.avg()
# d) s.sum() / s.len()
#
# **Ans:**s.mean()
#
#
# ###3. What will this print?
#
# s = pd.Series([10, 20, 30])
# print(s[1:3])
#
# a) 10, 20
# b) 10, 20, 30
# c) 20, 30
# d) 30
#
# **Ans:**20, 30
#
#
# ###4. Which of the following is NOT a valid way to create a Series?
#
# a) pd.Series([1, 2, 3])
# b) pd.Series({'a': 1, 'b': 2})
# c) pd.Series(1, 2, 3)
# d) pd.Series(range(5))
#
# **Ans:**pd.Series(1,2,3)
#
#
# ###5. What does s.index return?
#
# a) The values in the Series
# b) The data type of the Series
# c) The position of each element
# d) The labels of the Series elements
#
# **Ans**The labels of the Series elements
